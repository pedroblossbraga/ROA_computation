# %% [markdown]
# # Region Of Attraction (ROA) computation
#
#
# The dual of the problem can be formulated with the following optimization problem
# \begin{align}
# \inf & \int_X w(x)d \lambda(x) & \\
# \text{s.t. } & \mathcal{L} v(t,x,u) \leq 0, & \forall(t,x,u) \in [0,T] \times X \times U \\
# & w(x) \geq v(0,x) + 1, & \forall x \in X \\
# & v(t,x) \geq 0, & \forall (t,x) \in [0,T] \times X_T \\
# & w(x) \geq 0, & \forall x \in X \\
# \end{align}

# %% [markdown]
# ## Example 1: Univariave Cubic Dynamics
# \begin{align}
# \dot{x} = x(x-0.5)(x+0.5) \\
# X = [-1,1], T = 100, X_T = [-0.01, 0.01]
# \end{align}
# - The ROA is analytically found as $X_0 = [-0.5, 0.5]$.
# - Show polynomial approximations for degrees $d \in \{4, 8, 16, 32 \}$

# %%
# using Pkg
# Pkg.add("IntervalArithmetic")
# Pkg.add("JuMP")
# Pkg.add("SumOfSquares")
# Pkg.add("PolyJuMP")

# Pkg.rm("MosekTools")
# Pkg.add("MosekTools")
# Pkg.add("Plots")
# Pkg.add("DynamicPolynomials")
# Pkg.add("CSDP")
# Pkg.add("LazySets")

# Pkg.add("LaTeXStrings")
# Pkg.add("SCS")
# Pkg.add("Roots")

# %% [markdown]
# ## ROA computation

# %%
using Printf
using DynamicPolynomials
using LinearAlgebra
using JuMP
using SumOfSquares
using SCS
using MosekTools
using LazySets
using Plots
using IntervalArithmetic

function f(x)
    return x * (x - 0.5) * (x + 0.5)
end

function compute_roa(d, T, α, β, a, b, method="Mosek")
    """
    ----------------------------------------------------------------------
    Parameters:
    - d: degree of polynomial
    - T: terminal time
    - [α,β]: interval close to the stable equilibrium point
    - [a,b]: interval defining the set X
    Returns:
    - v and w solutions
    ----------------------------------------------------------------------
    """
    # Define the model
    if method == "SCS"
        model = Model(SCS.Optimizer) # Splitting Conic Solver, slow!
    else
        model = Model(Mosek.Optimizer)
    end
    
    @polyvar t x
    
    #----------------------------------------------------------------------
    # semialgebraic sets
    
    # [0,T] × X
    K = @set -t*(t-T) ≥0 && -(x-a)*(x-b) ≥0
    X = @set -(x-a)*(x-b) ≥0
    K_terminal = @set -t*(t-T) ≥0 && -(x-α)*(x-β) ≥0
    
    #----------------------------------------------------------------------
    # Define the Lyapunov function v(x) and the polynomial w(x)
    
    @variable(model, v, Poly(monomials([t, x], 0:d)))
    @variable(model, w, Poly(monomials(x, 0:d)))
    
    # Evaluate v(0,x)
    v_0 = subs(v, t=>0)
    
    #----------------------------------------------------------------------
    # Constraints
    
    # Defining L operator Lv = grad v * f + dv/dt
    Lv = differentiate(v, x) * f(x) + differentiate(v, t)
    
    # Lv(t,x) ≤ 0, ∀(t,x) ∈ [0,T] × X
    @constraint(model, -Lv in SOSCone(), domain=K)
    
    # w(x) ≥ v(0,x) + 1, ∀x ∈ X
    @constraint(model, w - v_0 - 1 in SOSCone(), domain=X)
    
    # v(T,x) ≥ 0, ∀(t,x) ∈ [0,T] × X_T
    @constraint(model, v in SOSCone(), domain=K_terminal)
    
    # w(x) ≥ 0, ∀x ∈ X
    @constraint(model, w in SOSCone(), domain=X)
    
    #----------------------------------------------------------------------
    # Objective: Minimize the integral of w over X (using fundamental Thm of calculus)
    
    @objective(model, Min, sum(w.a[i] * (b^(i) - a^(i)) / i for i in 1:d+1))
    
    #----------------------------------------------------------------------
    # Solve the problem
    optimize!(model)
    
    # Extract and return the solutions
    v_sol = value(v)
    w_sol = value(w)

    return v_sol, w_sol, x, t
end


function plot_results(x_vals, w_vals, d, method, w0)
    # Plot the polynomial approximation w(x)
    plot(x_vals, w_vals, label="w(x)", lw=2)
    xlabel!("x")
    ylabel!("Value")
    title!("Polynomial Approximation for ROA d=$(d) ($(method))")
    
    # Plot the ROA region
    x_roa = [-0.5, -0.5, 0.5, 0.5]
    y_roa = [0, 1, 1, 0]
    plot!(
        x_roa, y_roa,
        linestyle=:dash,
        seriescolor=:gray,
        label="ROA [-0.5, 0.5]"
    )
    scatter!([0], [w0], color=:red, label="w(0)=$(@sprintf("%.5f", w0))")
end

# ----------------------------------------------
function run_simulation(;
        d = 8,
        T = 100,
        α = -0.01,
        β = 0.01,
        a = -1,
        b = 1,
        method = "Mosek",
        verbose=true
        )
    v_sol, w_sol, x, t = compute_roa(d, T, α, β, a, b, method)
    
    if verbose
        # Print the results
        println("Lyapunov function coefficients v(x): \n$v_sol\n")
        println("Polynomial coefficients w(x): \n$w_sol\n")
    end

    x_vals = range(a, b, length=100)

    # Evaluate w(x) for the given range
    w_vals = [w_sol(x=>point) for point in x_vals]
    
    w0 = w_sol(0)
    println("w(0)=", w_sol(0))

    # Plot the results
    plot_results(x_vals, w_vals, d, method, w0)
end

run_simulation()
# Out:
# Problem
#   Name                   :
#   Objective sense        : minimize
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 129
#   Affine conic cons.     : 0
#   Disjunctive cons.      : 0
#   Cones                  : 0
#   Scalar variables       : 54
#   Matrix variables       : 10 (scalarized: 751)
#   Integer variables      : 0
#
# Optimizer started.
# Presolve started.
# Linear dependency checker started.
# Linear dependency checker terminated.
# Eliminator started.
# Freed constraints in eliminator : 0
# Eliminator terminated.
# Eliminator started.
# Freed constraints in eliminator : 0
# Eliminator terminated.
# Eliminator - tries                  : 2                 time                   : 0.00
# Lin. dep.  - tries                  : 1                 time                   : 0.00
# Lin. dep.  - primal attempts        : 1                 successes              : 1
# Lin. dep.  - dual attempts          : 0                 successes              : 0
# Lin. dep.  - primal deps.           : 0                 dual deps.             : 0
# Presolve terminated. Time: 0.01
# GP based matrix reordering started.
# GP based matrix reordering terminated.
# Optimizer  - threads                : 8
# Optimizer  - solved problem         : the primal
# Optimizer  - Constraints            : 129
# Optimizer  - Cones                  : 1
# Optimizer  - Scalar variables       : 55                conic                  : 55
# Optimizer  - Semi-definite variables: 10                scalarized             : 751
# Factor     - setup time             : 0.00
# Factor     - dense det. time        : 0.00              GP order time          : 0.00
# Factor     - nonzeros before factor : 7944              after factor           : 8385
# Factor     - dense dim.             : 0                 flops                  : 1.10e+06
# ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# 0   3.0e+00  2.0e+00  1.0e+00  0.00e+00   0.000000000e+00   0.000000000e+00   1.0e+00  0.02
# 1   1.0e+00  6.6e-01  1.5e-01  7.38e-01   1.094310975e+00   9.767348661e-01   3.3e-01  0.03
# 2   2.7e-01  1.8e-01  2.9e-02  8.96e-01   1.336072072e+00   1.338206142e+00   9.0e-02  0.03
# 3   1.1e-01  7.2e-02  9.3e-03  5.80e-01   1.078318802e+00   1.094258090e+00   3.6e-02  0.03
# 4   5.1e-02  3.4e-02  3.5e-03  7.29e-01   9.942529341e-01   1.007823396e+00   1.7e-02  0.03
# 5   1.5e-02  1.0e-02  7.4e-04  6.27e-01   8.703145721e-01   8.804257087e-01   5.1e-03  0.03
# 6   5.8e-03  3.9e-03  2.0e-04  7.02e-01   7.860980830e-01   7.918916097e-01   1.9e-03  0.04
# 7   2.0e-03  1.3e-03  5.9e-05  5.19e-01   7.315472799e-01   7.374843367e-01   6.5e-04  0.04
# 8   1.1e-03  7.5e-04  3.3e-05  2.97e-02   6.978883409e-01   7.040557032e-01   3.7e-04  0.04
# 9   3.3e-04  2.2e-04  5.7e-06  3.85e-01   6.253438123e-01   6.274497214e-01   1.1e-04  0.04
# 10  1.5e-04  1.0e-04  2.1e-06  7.52e-01   6.007450934e-01   6.021728501e-01   5.1e-05  0.04
003770399223356028*t^6 - 7.088038603918016e-15*x^7 - 152.36391139356104*t*x^6 - 1.71291915060108e-14*t^2*x^5 - 162.56847596503445*t^3*x^4 + 5.268756658678511e-15*t^4*x^3 + 2.8445420985015932*t^5*x^2 + 3.564672358726976e-18*t^6*x - 0.00010033757881546225*t^7 - 5.214441532768741*x^8 - 1.0483760214425448e-14*t*x^7 - 16.52021621451331*t^2*x^6 - 3.4066241607355573e-15*t^3*x^5 - 76.33601562127444*t^4*x^4 - 8.691919885507285e-16*t^5*x^3 - 0.6076341479845742*t^6*x^2 - 3.086359300263461e-19*t^7*x + 1.3567421830370234e-5*t^8
#
# Polynomial coefficients w(x):
# 1.0021393319777245 + 6.731527808456159e-19*x - 9.346307964074832*x^2 - 4.321240126583e-18*x^3 + 30.201124730900002*x^4 + 8.09579287802924e-18*x^5 - 39.21363207887456*x^6 - 4.6559873139831184e-18*x^7 + 17.640760559257284*x^8
#
# w(0)=1.0021393319777245

# %%
run_simulation()

# %%
Model(Mosek.Optimizer)
# Out:
# A JuMP Model
# Feasibility problem with:
# Variables: 0
# Model mode: AUTOMATIC
# CachingOptimizer state: EMPTY_OPTIMIZER
# Solver name: Mosek

# %% [markdown]
# ## $T=1$, $d \in \{4, 8, 16, 32\}$

# %%
function gather_results(;d=8, T=100, α=-0.01, β=0.01, a=-1, b=1, method="Mosek", verbose=true)
    v_sol, w_sol, x, t = compute_roa(d, T, α, β, a, b, method)
    
    if verbose
        # Print the results
        println("Lyapunov function coefficients v(x): \n$v_sol\n")
        println("Polynomial coefficients w(x): \n$w_sol\n")
    end

    x_vals = range(a, b, length=100)

    # Evaluate w(x) for the given range
    w_vals = [w_sol(x=>point) for point in x_vals]

    w0 = w_sol(0)
    return x_vals, w_vals, d, method, w0
end

function make_roa_box(v)
    x_roa = [-v, -v, v, v]
    y_roa = [0, 1, 1, 0]
    return x_roa, y_roa
end

function plot_all_results(results, output_filename)
    n = length(results)
    plot_grid = plot(layout=(1, n), size=(1200, 400))
    
    roa_box_colors=[:green, :orange, :red]
    
    for (i, (x_vals, w_vals, d, method, w0)) in enumerate(results)
        use_legend=:outerbottom
        
        plot!(plot_grid[i], x_vals, w_vals, label="w(x)", lw=2, 
            seriescolor=:blue,
            legend=use_legend,
            xlabel="x",
            title="d=$d, w(0)=$(@sprintf("%.5f", w0))"
        )
        xlabel!(plot_grid[i], "x")
        ylabel!(plot_grid[i], "Value")

        for (c, v) in enumerate([0.5, 0.25, 0.1])
            x_roa, y_roa = make_roa_box(v)
            plot!(
                plot_grid[i], x_roa, y_roa,
                linestyle=:dash, linewidth=2,
                seriescolor=roa_box_colors[c],
                label="[$(-v), $(v)]",
                use_legend=use_legend,
            )
        end
    end

    savefig(plot_grid, output_filename)
    display(plot_grid)
end

results = []
for d in [4, 8, 16, 32]
    push!(results, gather_results(d=d, T=1, 
                α=-0.01, β=0.01, a=-1, b=1, 
                method="Mosek", verbose=false))
end
plot_all_results(results, "roa_approximations_T1_d4_a_32_17jul24.png")
# Out:
# Problem
#   Name                   :
#   Objective sense        : minimize
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 53
#   Affine conic cons.     : 0
#   Disjunctive cons.      : 0
#   Cones                  : 2
#   Scalar variables       : 26
#   Matrix variables       : 8 (scalarized: 142)
#   Integer variables      : 0
#
# Optimizer started.
# Presolve started.
# Linear dependency checker started.
# Linear dependency checker terminated.
# Eliminator started.
# Freed constraints in eliminator : 0
# Eliminator terminated.
# Eliminator started.
# Freed constraints in eliminator : 0
# Eliminator terminated.
# Eliminator - tries                  : 2                 time                   : 0.00
# Lin. dep.  - tries                  : 1                 time                   : 0.00
# Lin. dep.  - primal attempts        : 1                 successes              : 1
# Lin. dep.  - dual attempts          : 0                 successes              : 0
# Lin. dep.  - primal deps.           : 0                 dual deps.             : 0
# Presolve terminated. Time: 0.00
# Optimizer  - threads                : 8
# Optimizer  - solved problem         : the primal
# Optimizer  - Constraints            :
# 27  1.2e-11  4.6e-12  2.3e-14  2.01e-01   2.710686547e-01   2.711734505e-01   2.3e-12  4.57
# Optimizer terminated. Time: 4.93

# %%
# possible test with larger degrees
# results = []
# for d in [30, 40, 50]
#     push!(results, gather_results(d=d, T=1, 
#                 α=-0.01, β=0.01, a=-1, b=1, 
#                 method="Mosek", verbose=false))
# end
# plot_all_results(results)

# %% [markdown]
# ## $T=100$, $d \in \{4, 8, 16, 32\}$

# %%
results = []
for d in [4, 8, 16, 32]
    push!(results, gather_results(d=d, T=100, 
                α=-0.01, β=0.01, a=-1, b=1, 
                method="Mosek", verbose=false))
end
plot_all_results(results, "roa_approximations_T100_d4_a_32_17jul24.png")
# Out:
# Problem
#   Name                   :
#   Objective sense        : minimize
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 53
#   Affine conic cons.     : 0
#   Disjunctive cons.      : 0
#   Cones                  : 2
#   Scalar variables       : 26
#   Matrix variables       : 8 (scalarized: 142)
#   Integer variables      : 0
#
# Optimizer started.
# Presolve started.
# Linear dependency checker started.
# Linear dependency checker terminated.
# Eliminator started.
# Freed constraints in eliminator : 0
# Eliminator terminated.
# Eliminator started.
# Freed constraints in eliminator : 0
# Eliminator terminated.
# Eliminator - tries                  : 2                 time                   : 0.00
# Lin. dep.  - tries                  : 1                 time                   : 0.00
# Lin. dep.  - primal attempts        : 1                 successes              : 1
# Lin. dep.  - dual attempts          : 0                 successes              : 0
# Lin. dep.  - primal deps.           : 0                 dual deps.             : 0
# Presolve terminated. Time: 0.00
# Optimizer  - threads                : 8
# Optimizer  - solved problem         : the primal
# Optimizer  - Constraints            : 53
# Optimizer  - Cones                  : 3
# Optimizer  - Scalar variables       : 27                conic                  : 27
# Optimizer  - Semi-definite variables: 8                 scalarized             : 142
# Factor     - setup time             : 0.00
# Factor     - dense det. time        : 0.00              GP order time          : 0.00
# Factor     - nonzeros before factor : 1256              after factor           : 1291
# Factor     - dense dim.             : 0                 flops                  : 5.97e+04
# ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# 0   2.7e+00  2.0e+00  1.0e+00  0.00e+00   0.000000000e+00   0.000000000e+00   1.0e+00  0.00
# 1   8.5e-01  6.3e-01  1.6e-01  6.27e-01   1.059102485e+00   9.928032847e-01   3.1e-01  0.00
# 2   1.9e-01  1.4e-01  2.4e-02  8.17e-01   1.425001168e+00   1.447678003e+00   7.2e-02  0.00
# 3   8.2e-02  6.1e-02  9.1e-03  4.22e-01   1.246674969e+00   1.282930397e+00   3.0e-02  0.00
# 4   2.8e-02  2.1e-02  2.3e-03  4.57e-01   1.057068391e+00   1.081516318e+00   1.0e-02  0.00
# 5   9.3e-03  6.9e-03  4.2e-04  8.23e-01   9.421019262e-01   9.491150709e-01   3.4e-03  0.00
# 6   1.9e-03  1.4e-03  3.9e-05  9.64e-01   9.011661690e-01   9.027336270e-01   6.9e-04  0.00
# 7   3.1e-04  2.3e-04  2.7e-06  1.00e+00   8.914940963e-01   8.917668241e-01   1.2e-04  0.01
# 8   5.5e-05  4.0e-05  1.8e-07  1.06e+00   8.896352100e-01   8.896722571e-01   2.0e-05  0.01
# 9   1.4e-05  1.0e-05  2.3e-08  1.14e+00   8.893135617e-01   8.893227554e-01   5.1e-06  0.01
# 10  4.5e-06  3.3e-06  5.1e-09  8.84e-01   8.892552519e-01   8.892605556e-01   1.7e-06  0.01
# 11  9.6e-07  7.1e-07  9.4e-10  4.74e-01   8.892731911e-01   8.892787771e-01   3.6e-07  0.01
# 12  3.4e-07  2.5e-07  3.8e-10  -5.65e-02  8.893398135e-01   8.893479585e-01   1.3e-07  0.01
# 13  1.1e-07  8.1e-08  1.7e-10  -3.58e-01  8.895013084e-01   8.895182209e-01   4.1e-08  0.01
# 14  3.8e-08  2.7e-08  9.0e-11  -6.02e-01  8.899377634e-01   8.899811013e-01   1.4e-08  0.01
# 15  8.2e-09  5.3e-09  4.1e-11  -9.37e-01  8.928838399e-01   8.931290780e-01   2.6e-09  0.01
# 16  1.2e-09  7.9e-10  1.4e-11  -9.89e-01  9.078844160e-01   9.091174343e-01   3.9e-10  0.01
# 17  2.3e-10  1.5e-10  4.9e-12  -8.41e-01  9.615375277e-01   9.659353153e-01   7.4e-11  0.01
# 1.0344396987889564 + 1.8568284852174212e-15*x - 36.20854439331866*x^2 - 5.954112636272351e-14*x^3 + 487.2926471608884*x^4 + 7.350642943318831e-13*x^5 - 3244.3943097936317*x^6 - 4.5522985058848765e-12*x^7 + 11720.13230130677*x^8 + 1.555650457972155e-11*x^9 - 22771.44991452494*x^10 - 2.940803609600231e-11*x^11 + 19481.008381328204*x^12 + 2.657700321450431e-11*x^13 + 2337.8651465103044*x^14 - 1.7648766407600417e-12*x^15 - 10432.823449213747*x^16 - 1.2733484585813353e-11*x^17 - 4553.136386365501*x^18 + 1.6056620457042475e-12*x^19 + 4163.927497847754*x^20 + 5.947522282355116e-12*x^21 + 5900.036163993393*x^22 - 1.7618066365243742e-12*x^23 + 2085.8382040813394*x^24 - 4.5074697639944626e-13*x^25 - 2245.7713521687524*x^26 + 3.800398753636631e-12*x^27 - 3761.908354376012*x^28 - 4.7878922432484e-12*x^29 - 3627.5807942959354*x^30 + 1.7223220248480757e-12*x^31 + 1621.9739429354033*x^32 - 1.8950219502273733e-12*x^33 + 2928.1781837046933*x^34 + 8.162315619816467e-13*x^35 + 1731.419125314092*x^36 + 8.891907029718866e-13*x^37 + 21.264954235611835*x^38 + 2.0746503651757273e-13*x^39 - 1035.9131828301963*x^40 + 2.9263321668968856e-13*x^41 - 1102.4490948670978*x^42 - 1.5998698336536072e-12*x^43 - 444.66499257412556*x^44 + 7.279083927825015e-13*x^45 + 330.46656776328854*x^46 + 5.142571406255386e-13*x^47 + 727.7382983912792*x^48 - 3.8045388571426936e-13*x^49 - 281.84539466058544*x^50
#
# w(0)=1.0344396987889564

# %% [markdown]
# ## Univariate Cubic Dynamics plot

# %%
using LaTeXStrings
using Plots

# Define the differential equation
function f(x)
    return x * (x - 0.5) * (x + 0.5)
end

# Define the differential equation
function f(dx, x, params, t)
    return x * (x - 0.5) * (x + 0.5)
end

# Solve for equilibrium points using DifferentialEquations.jl
equilibria = find_zeros(f, (-1.0, 1.0))

println("equilibrium points: $equilibria")

# Define a range of x values
x = range(-1, 1, length=400)

# Compute the corresponding y values (dx/dt = f(x))
y = f.(x)

# Create the plot object
p = plot(x, y, xlabel="x", ylabel=L"\dot{x}", 
    legend=true, label=L"\dot{x}",
    title=L"Direction Field for $\dot{x} = x(x-0.5)(x+0.5)$")

unstable_eq = [-0.5, 0.5]
stable_eq = [0]
scatter!(unstable_eq, [0,0], color=:orange, markersize=4, label="Unstable equilibrium: $unstable_eq", legend=true)
scatter!(stable_eq, [0], color=:green, markersize=4, label="Stable equilibrium: $stable_eq", legend=true)


# Display the plot
savefig(p, "univariate_cubic_dyn_01jul24.png")
display(p)
# Out:
# equilibrium points: [-0.5, 0.0, 0.5]

# %%
using Plots
using LaTeXStrings
using DifferentialEquations
using Roots

# Define the differential equation
function f(dx, x, params, t)
    return x * (x - 0.5) * (x + 0.5)
end

# Solve for equilibrium points using DifferentialEquations.jl
equilibria = find_zeros(f, (-3.0, 3.0))
equilibria
# Out:
# 3-element Vector{Float64}:
#  -0.5
#   0.0
#   0.5

# %%
equilibria
# Out:
# 3-element Vector{Float64}:
#  -0.5
#   0.0
#   0.5
